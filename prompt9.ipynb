# %%
import numpy as np 
import matplotlib.pyplot as plt

data = np.random.uniform(0, 1, 1000)
plt.hist(data, bins=100)

plt.xlabel
plt.ylabel
plt.title('histogram of 1000 distributed uniformly random numbers')
plt.show()
