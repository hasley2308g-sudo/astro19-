# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.binomial(n=20, p=0.7, size=1000)
plt.hist(data, bins=100)
plt.xlabel('value')
plt.ylabel('frenquency')
plt.title('histogram of binomail distributed random numbers')
plt.show()
